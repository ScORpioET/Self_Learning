# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,100)
y = x ** 2 + 15 * np.sin(x)
plt.plot(x,y)
plt.show()

# %%
w = torch.Tensor([10])
w.requires_grad = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3504\1990989917.py in <module>
# ----> 1 w = torch.Tensor([10])
#
# NameError: name 'torch' is not defined
